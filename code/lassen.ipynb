# %% [markdown]
# # Step 1: Import lassen_analysis script

# %%
# !pip install openpyxl # required to read in excel files

# %%
import sys
sys.path.append('./code')
import lassen_analysis as la

# %% [markdown]
# # Step 2: Load Data

# %%
df_eruptions_C00_D100_P00, df_summary_C00_D100_P00 = la.load_run_data("C00_D100_P00")

df_eruptions_C20_D30_P50, df_summary_C20_D30_P50 = la.load_run_data("C20_D30_P50")

df_eruptions_C60_D30_P10, df_summary_C60_D30_P10 = la.load_run_data("C60_D30_P10")

df_eruptions_C80_D15_P05, df_summary_C80_D15_P05 = la.load_run_data("C80_D15_P05")

# %% [markdown]
# # Step 3: Clean Data

# %%
df_eruptions_C00_D100_P00 = la.clean_settp_duplicates(df_eruptions_C00_D100_P00)

df_eruptions_C20_D30_P50 = la.clean_settp_duplicates(df_eruptions_C20_D30_P50)

df_eruptions_C60_D30_P10 = la.clean_settp_duplicates(df_eruptions_C60_D30_P10)

df_eruptions_C80_D15_P05 = la.clean_settp_duplicates(df_eruptions_C80_D15_P05)

# %% [markdown]
# # Step 4: Plot Oxides

# %%
df_list = [df_eruptions_C00_D100_P00, df_eruptions_C20_D30_P50, df_eruptions_C60_D30_P10, df_eruptions_C80_D15_P05]
run_names = ['C00_D100_P00', 'C20_D30_P50', 'C60_D30_P10', 'C80_D15_P05']

la.plot_all_oxides_vs_pressure(df_list, run_names)

# %% [markdown]
# # Step 5: Plot Temperature vs. Pressure

# %%
la.plot_temperature_vs_pressure(df_list, run_names)

# %% [markdown]
# # Step 6: Plot fluid mass versus pressure and temperature

# %%
la.plot_fluid_mass(df_list, run_names)
